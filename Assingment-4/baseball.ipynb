# %%
#Here import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Here load the dataset.
df = pd.read_csv("baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.shape
# Out:
# (30, 17)

# %%
df["W"].unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is no null values then we can go with EDA Process

# %% [markdown]
# # Exploratory Data Analysis(EDA) Process

# %%
# we will used to visualize the parametric distribution of a dataset
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.distplot(df['W'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %%
sns.distplot(df['R'])
# Out:
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %%
sns.distplot(df['AB'])
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Density'>

# %%
sns.distplot(df['H'])
# Out:
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %%
sns.distplot(df['2B'])
# Out:
# <AxesSubplot:xlabel='2B', ylabel='Density'>

# %%
sns.distplot(df['3B'])
# Out:
# <AxesSubplot:xlabel='3B', ylabel='Density'>

# %%
sns.distplot(df['HR'])
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Density'>

# %%
sns.distplot(df['BB'])
# Out:
# <AxesSubplot:xlabel='BB', ylabel='Density'>

# %%
sns.distplot(df['SO'])
# Out:
# <AxesSubplot:xlabel='SO', ylabel='Density'>

# %%
sns.distplot(df['SB'])
# Out:
# <AxesSubplot:xlabel='SB', ylabel='Density'>

# %%
sns.distplot(df['RA'])
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Density'>

# %%
sns.distplot(df['ER'])
# Out:
# <AxesSubplot:xlabel='ER', ylabel='Density'>

# %%
sns.distplot(df['ERA'])
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='Density'>

# %%
sns.distplot(df['CG'])
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Density'>

# %%
sns.distplot(df['SHO'])
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Density'>

# %%
sns.distplot(df['SV'])
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Density'>

# %%
sns.distplot(df['E'])
# Out:
# <AxesSubplot:xlabel='E', ylabel='Density'>

# %% [markdown]
# we can see the density of data between 80-100

# %%
# check the correlation of data
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %% [raw]
# Correlation using Heatmap

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True ,linewidths=0.5,linecolor='black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [raw]
# As per correlation and heatmap the following features have lesser relation with the target value
# "E"=-0.089485,-0.09,
# "AB"=-0.087947,-0.09
# "SB"=-0.157234,-0.16
# "3B"=-0.251118,-0.25 respectively
#
# Here "E" stands for "Error" which is not impact on our target value therefore we are going to skew only "AB","SB","3B","E","RA","ER","ERA","E"

# %%
# we will use describe function to check the stats of our data like mean,std,min,max etc
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
# check the describe part in heatmap format
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("BaseBall")
plt.show()

# %%
# we will use scatter plot to check to frequency of data
import seaborn as sns
sns.scatterplot(x='R',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %%
sns.scatterplot(x='AB',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='W'>

# %%
sns.scatterplot(x='H',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='H', ylabel='W'>

# %%
sns.scatterplot(x='2B',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='W'>

# %%
sns.scatterplot(x='3B',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='W'>

# %%
sns.scatterplot(x='HR',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='W'>

# %%
sns.scatterplot(x='BB',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='W'>

# %%
sns.scatterplot(x='SO',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='W'>

# %%
sns.scatterplot(x='SB',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SB', ylabel='W'>

# %%
sns.scatterplot(x='RA',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='W'>

# %%
sns.scatterplot(x='ER',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='W'>

# %%
sns.scatterplot(x='ERA',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='W'>

# %%
sns.scatterplot(x='CG',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='W'>

# %%
sns.scatterplot(x='SHO',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='W'>

# %%
sns.scatterplot(x='SV',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='W'>

# %%
sns.scatterplot(x='E',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='E', ylabel='W'>

# %%
df.hist(edgecolor='red',linewidth=1.5,figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'W'}>,
#         <AxesSubplot:title={'center':'R'}>,
#         <AxesSubplot:title={'center':'AB'}>,
#         <AxesSubplot:title={'center':'H'}>],
#        [<AxesSubplot:title={'center':'2B'}>,
#         <AxesSubplot:title={'center':'3B'}>,
#         <AxesSubplot:title={'center':'HR'}>,
#         <AxesSubplot:title={'center':'BB'}>],
#        [<AxesSubplot:title={'center':'SO'}>,
#         <AxesSubplot:title={'center':'SB'}>,
#         <AxesSubplot:title={'center':'RA'}>,
#         <AxesSubplot:title={'center':'ER'}>],
#        [<AxesSubplot:title={'center':'ERA'}>,
#         <AxesSubplot:title={'center':'CG'}>,
#         <AxesSubplot:title={'center':'SHO'}>,
#         <AxesSubplot:title={'center':'SV'}>],
#        [<AxesSubplot:title={'center':'E'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [raw]
# Here we can see and check the data in a Group

# %%
# here we can check skew of our data
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [raw]
# skewness: from the above observation the columns falls under normal skewness:
#
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
#
# some skewness are present so need to do Data Transformation

# %% [markdown]
# # The normal distribution shows that the data is skewed.
# Data Cleaning:

# %%
delete = pd.DataFrame([["-0.087947","AB","No","Alot"],["-0.251118","3B","No","Alot"],["-0.157234","SB","No","Alot"],["-0.812952","RA","No","Alot"],["-0.809435","ER","No","Alot"],["-0.819600","ERA","No","Alot"],["-0.089485","E","No","Alot"]],columns=["Correlation with Target","Column Name","Normalised","Outliers"])
delete
# Out:
#   Correlation with Target Column Name Normalised Outliers
# 0               -0.087947          AB         No     Alot
# 1               -0.251118          3B         No     Alot
# 2               -0.157234          SB         No     Alot
# 3               -0.812952          RA         No     Alot
# 4               -0.809435          ER         No     Alot
# 5               -0.819600         ERA         No     Alot
# 6               -0.089485           E         No     Alot

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
# outliers check
df["W"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["R"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["AB"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["H"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["2B"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["3B"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["HR"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["BB"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["SO"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["SB"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["RA"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["ER"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["ERA"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["CG"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["SHO"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["SV"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["E"].plot.box()
# Out:
# <AxesSubplot:>

# %% [raw]
# As per the box plot graphs data are normal very few outliers are avail in the data.

# %% [markdown]
# # Removing outliers
#
# Z-Score Technique

# %%
# applying zscore
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z
# Out:
# array([[1.36540860e+00, 6.19077968e-01, 8.47731264e-01, 1.66368512e+00,
#         1.42017307e+00, 1.04119304e+00, 7.87298598e-01, 1.53490242e+00,
#         2.69762957e+00, 9.13883291e-01, 6.66233927e-01, 5.05110079e-01,
#         5.06955186e-01, 5.39806195e-01, 8.14628593e-01, 1.67160651e+00,
#         4.61469635e-01],
#        [1.97838300e-01, 1.34431656e-01, 7.11093535e-01, 9.70680764e-01,
#         1.27403389e-01, 1.23580856e+00, 2.43966683e-01, 5.36591904e-01,
#         1.54878442e-01, 6.01825582e-01, 1.65970766e-01, 2.48929848e-01,
#         2.54597523e-01, 5.39806195e-01, 1.72800005e-01, 2.49879323e-01,
#         6.07196888e-01],
#        [3.24325082e-03, 3.32905860e-01, 1.11523330e+00, 1.51891367e-01,
#         1.58879521e+00, 2.23807850e-01, 7.23377196e-01, 1.13914361e+00,
#         8.93981893e-01, 1.11449182e-01, 6.80339091e-01, 7.51623132e-01,
#         6.41346840e-01, 2.77264091e+00, 3.20914294e-01, 6.54856158e-01,
#         1.11724227e+00],
# ...

# %%
threshold=3
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df=df[(z<3).all(axis=1)]

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %%
df.shape
# Out:
# (29, 17)

# %% [markdown]
# # Percentage loss of data while removing outliers

# %%
percentage_loss = ((30-29)/30)*100
print(percentage_loss)
# Out:
# 3.3333333333333335

# %%
x=df.iloc[:,1:]
x
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# 11  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5   13
# ...

# %%
x.columns
# Out:
# Index(['R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER', 'ERA',
#        'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
y=df.iloc[:,:1]
y
# Out:
#       W
# 0    95
# 1    83
# 2    81
# 3    76
# 4    74
# 6    87
# 7    81
# 8    80
# 9    78
# 10   88
# 11   86
# 12   85
# 13   76
# 14   68
# 15  100
# 16   98
# 17   97
# 18   68
# 19   64
# 20   90
# 21   83
# 22   71
# 23   67
# 24   63
# 25   92
# 26   84
# 27   79
# 28   74
# 29   68

# %%
y.columns
# Out:
# Index(['W'], dtype='object')

# %%
x=df.iloc[:,1:]
y=df.iloc[:,:1]

# %% [raw]
# Above data had define x and y values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=0)

# %% [markdown]
# # Removing skewness by transforming the data

# %%
# Removing skewness
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 9.62543504e-01,  0.00000000e+00,  0.00000000e+00,
#          1.68518793e+00,  1.00615029e+00, -7.41927000e-01,
#         -1.60519802e+00, -2.55061247e+00,  9.36131648e-01,
#         -6.60978697e-01, -5.08052227e-01, -5.09292146e-01,
#         -3.07098204e-01, -7.87002186e-01,  1.53275292e+00,
#         -3.48265262e-01],
#        [ 2.98863300e-01,  0.00000000e+00,  0.00000000e+00,
#          1.38197902e-01,  1.18522654e+00, -1.09958425e-01,
#         -4.62095966e-01,  9.36832915e-02, -5.16377335e-01,
#          1.60225829e-01,  2.35800484e-01,  2.41440214e-01,
#         -3.07098204e-01,  2.36736538e-01,  3.12020186e-01,
#         -5.40819806e-01],
#        [-3.12105130e-01,  0.00000000e+00,  0.00000000e+00,
#          1.90738550e+00, -2.28819392e-01, -6.64354121e-01,
#          1.23209786e+00, -9.35611465e-01,  2.25038365e-01,
#         -6.74967476e-01, -7.52213883e-01, -6.42097599e-01,
#          2.01131531e+00, -2.52844176e-01, -6.64136739e-01,
#         -1.32612477e+00],
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 9.62543504e-01,  0.00000000e+00,  0.00000000e+00,
#          1.68518793e+00,  1.00615029e+00, -7.41927000e-01,
#         -1.60519802e+00, -2.55061247e+00,  9.36131648e-01,
#         -6.60978697e-01, -5.08052227e-01, -5.09292146e-01,
#         -3.07098204e-01, -7.87002186e-01,  1.53275292e+00,
#         -3.48265262e-01],
#        [ 2.98863300e-01,  0.00000000e+00,  0.00000000e+00,
#          1.38197902e-01,  1.18522654e+00, -1.09958425e-01,
#         -4.62095966e-01,  9.36832915e-02, -5.16377335e-01,
#          1.60225829e-01,  2.35800484e-01,  2.41440214e-01,
#         -3.07098204e-01,  2.36736538e-01,  3.12020186e-01,
#         -5.40819806e-01],
#        [-3.12105130e-01,  0.00000000e+00,  0.00000000e+00,
#          1.90738550e+00, -2.28819392e-01, -6.64354121e-01,
#          1.23209786e+00, -9.35611465e-01,  2.25038365e-01,
#         -6.74967476e-01, -7.52213883e-01, -6.42097599e-01,
#          2.01131531e+00, -2.52844176e-01, -6.64136739e-01,
#         -1.32612477e+00],
# ...

# %% [markdown]
# # Since the outcome has continuous variable hence we will use Linear Regression with classification.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
from sklearn.metrics import accuracy_score

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, random_state=0, test_size=0.20)
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_y = lm.predict(x_test)
pred_y
# Out:
# array([[82.60417999],
#        [88.70394359],
#        [58.82773938],
#        [77.92725107],
#        [82.38625909],
#        [90.40284503]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"At random state {i}, the training accuracy is:- {r2_score(y_train,pred_train)}")
    print(f"At random state {i}, the testing accuracy is:- {r2_score(y_test,pred_test)}")
    print('\n')
# Out:
# At random state 0, the training accuracy is:- 0.9721988993735987
# At random state 0, the testing accuracy is:- 0.5493326935439179
#
#
# At random state 1, the training accuracy is:- 0.9530846867182348
# At random state 1, the testing accuracy is:- 0.8368467860007267
#
#
# At random state 2, the training accuracy is:- 0.948973185944343
# At random state 2, the testing accuracy is:- 0.33616518353344294
#
#
# At random state 3, the training accuracy is:- 0.9415620923644433
# At random state 3, the testing accuracy is:- 0.9211876785620994
#
#
# At random state 4, the training accuracy is:- 0.9630193905006124
# At random state 4, the testing accuracy is:- 0.7284939349262083
#
#
# At random state 5, the training accuracy is:- 0.9641063670889382
# At random state 5, the testing accuracy is:- 0.5877179711445887
#
#
# At random state 6, the training accuracy is:- 0.949461590703979
# At random state 6, the testing accuracy is:- 0.8095098270789228
#
#
# ...

# %% [markdown]
# we find the accuracy of train and test but training is greater than testing accuracy so as per process this data is coming "OVERFITTING".

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Regularization:

# %% [markdown]
# # 1.Lasso & 2.Ridge

# %%
from sklearn.linear_model import Lasso
ls=Lasso(alpha=0.0001)
#ls=lasso(alpha=1.0) # Default
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
# Out:
# 0.9477706001530845

# %%
from sklearn.linear_model import Ridge

#parameters = {'alpha':[.0001,.001,.01,.1,1],'fit_intercept':[True,False],'normalize':[True,False],'copy_x':[True,False],'tol':[0.001,.001,.01,.1,1],'random_state':[0]}
#rd = Ridge()
#clf = GridSearchCV(rd,parameters)
#clf.fit(x_train,y_train)
#print(clf.best_params_)

rd=Ridge(alpha=0.0001)
#ridge=Ridge
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
# Out:
# 0.9477709942815007

# %%
from sklearn.linear_model import Lasso

parameters = {'alpha':[.0001, .001, .01, .1, 1, 10],'random_state':list(range(0,10))}
ls = Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
ls = Lasso(alpha=0.1,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls = ls.predict(x_test)

lss = r2_score(y_test,pred_ls)
for j in range(2,10):
    lsscore = cross_val_score(ls,x,y,cv=j)
    lsc = lsscore.mean()
    print("At cv:-",j)
    print("Cross validation score is:-",lsc*100 )
    print("R2_score is :-",lss*100)
    print("\n")
# Out:
# At cv:- 2
# Cross validation score is:- 66.26738353988556
# R2_score is :- 93.82818349329243
#
#
# At cv:- 3
# Cross validation score is:- 54.51262749228722
# R2_score is :- 93.82818349329243
#
#
# At cv:- 4
# Cross validation score is:- 61.299407593117685
# R2_score is :- 93.82818349329243
#
#
# At cv:- 5
# Cross validation score is:- 47.37613534043356
# R2_score is :- 93.82818349329243
#
#
# At cv:- 6
# Cross validation score is:- 48.022585044816246
# R2_score is :- 93.82818349329243
#
#
# At cv:- 7
# Cross validation score is:- 36.183917097664356
# R2_score is :- 93.82818349329243
#
#
# At cv:- 8
# Cross validation score is:- 51.99178385312283
# R2_score is :- 93.82818349329243
#
#
# At cv:- 9
# Cross validation score is:- -455.98490165605637
# R2_score is :- 93.82818349329243

# %%
print("At cv:-",2)
print("Cross validation score is:-",66.26)
print("R2_score is :-",93.82)
# Out:
# At cv:- 2
# Cross validation score is:- 66.26
# R2_score is :- 93.82

# %%
from sklearn.linear_model import ElasticNet
enr=ElasticNet(alpha=0.0001)
enr.fit(x_train,y_train)
enrpred=enr.predict(x_test)
print(enr.score(x_train,y_train))
enr.coef_
# Out:
# 0.9477696402006123
# array([  5.86457258,   0.        ,   0.        ,  -2.24477836,
#         -0.2192047 ,  -1.9601327 ,  -1.39446386,  -0.11548896,
#         -0.31280188,  11.60606694, -11.82948251,  -5.24583817,
#          2.64051429,   1.30520758,   5.73786346,  -0.72034741])

# %% [raw]
# We are checking multiple time of accuracy to see it here is the value of Cross_Validation is 66.26, and R2_Score is 93.82

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y, random_state=i,test_size=0.20)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
print('Error')

print('Mean Absolute Error:', mean_absolute_error(y_test,pred_ls))
print('Mean Squared Error:', mean_squared_error(y_test,pred_ls))
print('Root Mean Square Error:',np.sqrt(mean_squared_error(y_test,pred_ls)))
# Out:
# Error
# Mean Absolute Error: 2.816994986232919
# Mean Squared Error: 9.415448959677223
# Root Mean Square Error: 3.0684603565432003

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=pred_ls, color='r')
plt.plot(y_test,y_test, color='b')
plt.xlabel('Actual compressive strength',fontsize=14)
plt.ylabel('Predicted compressive strength',fontsize=14)
plt.title('Lasso Regression',fontsize=18)
plt.show()

# %% [markdown]
# # Ensemble Techniques:

# %%
from sklearn.tree import DecisionTreeRegressor

parameters = {'criterion':['mse', 'friedman_mse', 'mae'], 'splitter':['best','random']}
dt =DecisionTreeRegressor()
clf = GridSearchCV(dt,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'splitter': 'random'}

# %%
dt = DecisionTreeRegressor(criterion='friedman_mse', splitter='best')
dt.fit(x_train,y_train)
dt.score(x_train,y_train)
pred_decision = dt.predict(x_test)

dts = r2_score(y_test,pred_decision)
print('R2 Score:',dts*100)

dtscore = cross_val_score(dt,x,y,cv=3)
dtc = dtscore.mean()
print('Cross Val Score:',dtc*100)
# Out:
# R2 Score: 63.729060451565914
# Cross Val Score: -49.11040594915406

# %%
print('Error')

print('Mean Absolute Error:', mean_absolute_error(y_test,pred_decision))
print('Mean Squared Error:', mean_squared_error(y_test,pred_decision))
print('Root Mean Square Error:',np.sqrt(mean_squared_error(y_test,pred_decision)))
# Out:
# Error
# Mean Absolute Error: 6.333333333333333
# Mean Squared Error: 55.333333333333336
# Root Mean Square Error: 7.438637868140466

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=pred_decision, color='r')
plt.plot(y_test,y_test, color='b')
plt.xlabel('Actual Happiness Score',fontsize=14)
plt.ylabel('Predicted Happiness Score',fontsize=14)
plt.title('Decision Tree Regression',fontsize=18)
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

parameters = {'criterion':['friedman_mse', 'mae'],'n_estimators':[100,200,300]}
rf = RandomForestRegressor()
clf = GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'friedman_mse', 'n_estimators': 100}

# %%
rf = RandomForestRegressor(criterion='mae',n_estimators=200)
rf.fit(x_train, y_train)
rf.score(x_train, y_train)
pred_random = rf.predict(x_test)

rfs = r2_score(y_test,pred_random)
print('R2 Score:',rfs*100)

rfscore = cross_val_score(rf,x,y,cv=3)
rfc = rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2 Score: 68.68177257829569
# Cross Val Score: -8.28953981702737

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=pred_random, color='r')
plt.plot(x_test,y_test, color='b')
plt.xlabel('Actual Compressive strengh',fontsize=14)
plt.ylabel('Predicted Compressive strengh',fontsize=14)
plt.title('Random Forest Regression',fontsize=18)
plt.show()

# %%
from sklearn.datasets import make_regression
from sklearn.ensemble import GradientBoostingRegressor
parameters = {'loss':['ls','lad','huber','quantile'],'n_estimators':[50,100,200]}
gbr = GradientBoostingRegressor()
clf = GridSearchCV(gbr,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'loss': 'lad', 'n_estimators': 50}

# %%
gbr = GradientBoostingRegressor(criterion='friedman_mse',loss='huber',n_estimators=200)
gbr.fit(x_train,y_train)
gbr.score(x_train,y_train)
pred_random = rf.predict(x_test)

gbrs = r2_score(y_test,pred_random)
print('R2 Score:',gbrs*100)

gbscore = cross_val_score(gbr,x,y,cv=3)
gbrc= gbscore.mean()
print('Cross Val Score:',gbrc*100)
# Out:
# R2 Score: 68.68177257829569
# Cross Val Score: -40.09639039673001

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=pred_random, color='r')
plt.plot(x_test,y_test, color='b')
plt.xlabel('Actual Compressive strengh',fontsize=14)
plt.ylabel('Predicted Compressive strengh',fontsize=14)
plt.title('Gradient Boost Regressor',fontsize=18)
plt.show()

# %%
from sklearn.svm import SVR

parameters = {'kernel':['linear','poly','rbf','sigmoid']}  #'gamma':['auto','scale']
sv = SVR()
clf = GridSearchCV(sv,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'kernel': 'linear'}

# %%
sv = SVR(kernel = 'linear', gamma= 'auto')
sv.fit(x_train, y_train)
sv.score(x_train,y_train)
pred_vector = sv.predict(x_test)

svs = r2_score(y_test,pred_vector)
print('R2 Score:',svs*100)

svscore = cross_val_score(sv,x,y,cv=3)
svc = svscore.mean()
print('Cross Val Score:',svc*100)
# Out:
# R2 Score: 91.31781229611998
# Cross Val Score: 40.09867882195589

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=pred_random, color='r')
plt.plot(x_test,y_test, color='b')
plt.xlabel('Actual Compressive strengh',fontsize=14)
plt.ylabel('Predicted Compressive strengh',fontsize=14)
plt.title('Support Vector Regressor',fontsize=18)
plt.show()

# %% [markdown]
# # From the above observation:-
#
# it is clear that through ensemble techniques we are worked on overfitting of model.
#
# The best model is SVR. Since the difference between the percentage score of cross validation and R2_score is optimum.
#
# SVR Model is:-
#
# R2 Score:=: 91.31781229611998
#
# Cross Val Score:=:    40.09867882195589

# %%
#Model Saving

import pickle
filename = 'baseballl.pkl'
pickle.dump(ls, open(filename, 'wb'))

# %% [markdown]
# # Conclusion:

# %%
import numpy as np
a=np.array(y_test)
a
# Out:
# array([[67],
#        [63],
#        [97],
#        [76],
#        [83],
#        [92]], dtype=int64)

# %%
predicted = np.array(ls.predict(x_test))
predicted
# Out:
# array([69.5572137 , 61.19768737, 92.06397966, 77.20840719, 86.65352512,
#        89.25550906])

# %%
y_test
# Out:
#      W
# 23  67
# 24  63
# 17  97
# 13  76
# 21  83
# 25  92

# %%
df_com=pd.DataFrame({"predicted":predicted}, index=range(len(a)))

# %%
df_com
# Out:
#    predicted
# 0  69.557214
# 1  61.197687
# 2  92.063980
# 3  77.208407
# 4  86.653525
# 5  89.255509

# %% [markdown]
# # From the above table the model is predicted the value with 91-92 percent accuracy.
